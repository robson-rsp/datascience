# %% [markdown]
# This dataset contains prices of New York houses, providing valuable insights into the real estate market in the region. It includes information such as broker titles, house types, prices, number of bedrooms and bathrooms, property square footage, addresses, state, administrative and local areas, street names, and geographical coordinates.
#
# **Key** Features:
#
# * BROKERTITLE: Title of the broker
# * TYPE: Type of the house
# * PRICE: Price of the house
# * BEDS: Number of bedrooms
# * BATH: Number of bathrooms
# * PROPERTYSQFT: Square footage of the property
# * ADDRESS: Full address of the house
# * STATE: State of the house
# * MAIN_ADDRESS: Main address information
# * ADMINISTRATIVE_AREA_LEVEL_2: Administrative area level 2 information
# * LOCALITY: Locality information
# * SUBLOCALITY: Sublocality information
# * STREET_NAME: Street name
# * LONG_NAME: Long name
# * FORMATTED_ADDRESS: Formatted address
# * LATITUDE: Latitude coordinate of the house
# * LONGITUDE: Longitude coordinate of the house
#
# Potential Use Cases:
#
# * Price analysis: Analyze the distribution of house prices to understand market trends and identify potential investment opportunities.
# * Property size analysis: Explore the relationship between property square footage and prices to assess the value of different-sized houses.
# * Location-based analysis: Investigate geographical patterns to identify areas with higher or lower property prices.
# * Bedroom and bathroom trends: Analyze the impact of the number of bedrooms and bathrooms on house prices.
# * Broker performance analysis: Evaluate the influence of different brokers on the pricing of houses.

# %%
# %pip install ipython-autotime
# Out:
# Requirement already satisfied: ipython-autotime in /usr/local/lib/python3.10/dist-packages (0.3.2)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from ipython-autotime) (7.34.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->ipython-autotime) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->ipython-autotime) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->ipython-autotime) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipython-autotime) (0.2.12)
# time: 19 s (started: 2024-01-13 13:52:16 +00:00)

# %%
from google.colab import drive, files
import pandas as pd

drive.mount('/content/drive', force_remount=True)
# %load_ext autotime
# Out:
# Mounted at /content/drive
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 3.3 s (started: 2024-01-13 13:52:35 +00:00)

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/datasets/ny-house-dataset.csv', encoding='utf-8')
# Out:
# time: 83.1 ms (started: 2024-01-13 13:52:38 +00:00)

# %% [markdown]
# # EDA

# %%
df
# Out:
#                                             BROKERTITLE                TYPE  \
# 0           Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                   Brokered by Serhant      Condo for sale
# 2                                Brokered by Sowae Corp      House for sale
# 3                                   Brokered by COMPASS      Condo for sale
# 4     Brokered by Sotheby's International Realty - E...  Townhouse for sale
# ...                                                 ...                 ...
# 4796                                Brokered by COMPASS      Co-op for sale
# 4797                    Brokered by Mjr Real Estate Llc      Co-op for sale
# 4798      Brokered by Douglas Elliman - 575 Madison Ave      Co-op for sale
# 4799            Brokered by E Realty International Corp      Condo for sale
# 4800                 Brokered by Nyc Realty Brokers Llc      Co-op for sale
#
#           PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0        315000     2   2.000000   1400.000000
# 1     195000000     7  10.000000  17545.000000
# 2        260000     4   2.000000   2015.000000
# 3         69000     3   1.000000    445.000000
# 4      55000000     7   2.373861  14175.000000
# ...         ...   ...        ...           ...
# 4796     599000     1   1.000000   2184.207862
# 4797     245000     1   1.000000   2184.207862
# 4798    1275000     1   1.000000   2184.207862
# 4799     598125     2   1.000000    655.000000
# 4800     349000     1   1.000000    750.000000
#
#                                                 ADDRESS  \
# 0                                  2 E 55th St Unit 803
# 1     Central Park Tower Penthouse-217 W 57th New Yo...
# 2                                      620 Sinclair Ave
# 3                               2 E 55th St Unit 908W33
# 4                                           5 E 64th St
# ...                                                 ...
# 4796                               222 E 80th St Apt 3A
# 4797                                97-40 62 Dr Unit Lg
# 4798                          427 W 21st St Unit Garden
# 4799                           91-23 Corona Ave Unit 4G
# 4800                            460 Neptune Ave Apt 14O
#
#                         STATE  \
# 0          New York, NY 10022
# 1          New York, NY 10019
# 2     Staten Island, NY 10312
# 3         Manhattan, NY 10022
# 4          New York, NY 10065
# ...                       ...
# 4796      Manhattan, NY 10075
# 4797      Rego Park, NY 11374
# 4798       New York, NY 10011
# 4799       Elmhurst, NY 11373
# 4800       Brooklyn, NY 11224
#
#                                            MAIN_ADDRESS  \
# 0                2 E 55th St Unit 803New York, NY 10022
# 1     Central Park Tower Penthouse-217 W 57th New Yo...
# 2               620 Sinclair AveStaten Island, NY 10312
# 3            2 E 55th St Unit 908W33Manhattan, NY 10022
# 4                         5 E 64th StNew York, NY 10065
# ...                                                 ...
# 4796            222 E 80th St Apt 3AManhattan, NY 10075
# 4797             97-40 62 Dr Unit LgRego Park, NY 11374
# 4798        427 W 21st St Unit GardenNew York, NY 10011
# 4799         91-23 Corona Ave Unit 4GElmhurst, NY 11373
# 4800          460 Neptune Ave Apt 14OBrooklyn, NY 11224
#
#      ADMINISTRATIVE_AREA_LEVEL_2         LOCALITY      SUBLOCALITY  \
# 0                New York County         New York        Manhattan
# 1                  United States         New York  New York County
# 2                  United States         New York  Richmond County
# 3                  United States         New York  New York County
# 4                  United States         New York  New York County
# ...                          ...              ...              ...
# 4796                    New York  New York County         New York
# 4797               United States         New York    Queens County
# 4798               United States         New York  New York County
# 4799                    New York    Queens County           Queens
# 4800                    New York     Kings County         Brooklyn
#
#            STREET_NAME         LONG_NAME  \
# 0     East 55th Street   Regis Residence
# 1             New York  West 57th Street
# 2        Staten Island   Sinclair Avenue
# 3             New York  East 55th Street
# 4             New York  East 64th Street
# ...                ...               ...
# 4796         Manhattan               222
# 4797            Queens        62nd Drive
# 4798          New York  West 21st Street
# 4799          Flushing             91-23
# 4800      Coney Island               460
#
#                                       FORMATTED_ADDRESS   LATITUDE  LONGITUDE
# 0     Regis Residence, 2 E 55th St #803, New York, N...  40.761255 -73.974483
# 1                217 W 57th St, New York, NY 10019, USA  40.766393 -73.980991
# 2        620 Sinclair Ave, Staten Island, NY 10312, USA  40.541805 -74.196109
# 3                  2 E 55th St, New York, NY 10022, USA  40.761398 -73.974613
# 4                  5 E 64th St, New York, NY 10065, USA  40.767224 -73.969856
# ...                                                 ...        ...        ...
# 4796         222 E 80th St #3a, New York, NY 10075, USA  40.774350 -73.955879
# 4797            97-40 62nd Dr, Rego Park, NY 11374, USA  40.732538 -73.860152
# 4798             427 W 21st St, New York, NY 10011, USA  40.745882 -74.003398
# 4799     91-23 Corona Ave. #4b, Flushing, NY 11373, USA  40.742770 -73.872752
# 4800      460 Neptune Ave #14a, Brooklyn, NY 11224, USA  40.579147 -73.970949
#
# [4801 rows x 17 columns]
# time: 27.5 ms (started: 2024-01-13 13:52:38 +00:00)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4801 entries, 0 to 4800
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   BROKERTITLE                  4801 non-null   object
#  1   TYPE                         4801 non-null   object
#  2   PRICE                        4801 non-null   int64
#  3   BEDS                         4801 non-null   int64
#  4   BATH                         4801 non-null   float64
#  5   PROPERTYSQFT                 4801 non-null   float64
#  6   ADDRESS                      4801 non-null   object
#  7   STATE                        4801 non-null   object
#  8   MAIN_ADDRESS                 4801 non-null   object
#  9   ADMINISTRATIVE_AREA_LEVEL_2  4801 non-null   object
#  10  LOCALITY                     4801 non-null   object
#  11  SUBLOCALITY                  4801 non-null   object
#  12  STREET_NAME                  4801 non-null   object
#  13  LONG_NAME                    4801 non-null   object
#  14  FORMATTED_ADDRESS            4801 non-null   object
#  15  LATITUDE                     4801 non-null   float64
#  16  LONGITUDE                    4801 non-null   float64
# dtypes: float64(4), int64(2), object(11)
# memory usage: 637.8+ KB
# time: 31 ms (started: 2024-01-13 13:52:38 +00:00)

# %% [markdown]
# I'm going to convert the feature names to lowecase because I like them this way. And convert BATH and PROPERTYSQFT to int.

# %%
columns_original = list(df.columns)
columns_lower = list(map(lambda x: x.lower(), columns_original))
columns_new = {key: value for (key, value) in zip(columns_original, columns_lower)}
df.rename(columns=columns_new, inplace=True)
# Out:
# time: 2.64 ms (started: 2024-01-13 13:52:38 +00:00)

# %%
df = df.astype({"bath": int, "propertysqft": int})
# Out:
# time: 11.2 ms (started: 2024-01-13 13:52:38 +00:00)

# %%
df[['price', 'beds', 'bath', 'propertysqft', 'latitude', 'longitude']].describe()
# Out:
#               price         beds         bath  propertysqft     latitude  \
# count  4.801000e+03  4801.000000  4801.000000   4801.000000  4801.000000
# mean   2.356940e+06     3.356801     2.350344   2184.137680    40.714227
# std    3.135525e+07     2.602315     1.949077   2377.140896     0.087676
# min    2.494000e+03     1.000000     0.000000    230.000000    40.499546
# 25%    4.990000e+05     2.000000     1.000000   1200.000000    40.639375
# 50%    8.250000e+05     3.000000     2.000000   2184.000000    40.726749
# 75%    1.495000e+06     4.000000     3.000000   2184.000000    40.771923
# max    2.147484e+09    50.000000    50.000000  65535.000000    40.912729
#
#          longitude
# count  4801.000000
# mean    -73.941601
# std       0.101082
# min     -74.253033
# 25%     -73.987143
# 50%     -73.949189
# 75%     -73.870638
# max     -73.702450
# time: 35.4 ms (started: 2024-01-13 13:52:39 +00:00)

# %% [markdown]
# ## Location features

# %%
import re
# Out:
# time: 563 µs (started: 2024-01-13 13:52:39 +00:00)

# %% [markdown]
# It seems to me that this dataset contains redundant features. I'm referring to those about the location of the houses. I'm going to take a closer look on these features.

# %%
df[['address', 'state', 'main_address', 'administrative_area_level_2', 'locality', 'sublocality', 'street_name', 'long_name', 'formatted_address']].sample(5)
# Out:
#                           address                state  \
# 3014          1893 Longfellow Ave      Bronx, NY 10460
# 958      2390 Palisade Ave Apt 4K      Bronx, NY 10463
# 3139        205 E 63rd St Apt 19E   New York, NY 10065
# 1457      61-20 71st Ave Unit F2A  Ridgewood, NY 11385
# 4757  800 Grand Concourse Apt Gms      Bronx, NY 10451
#
#                                     main_address administrative_area_level_2  \
# 3014          1893 Longfellow AveBronx, NY 10460               United States
# 958      2390 Palisade Ave Apt 4KBronx, NY 10463                    New York
# 3139     205 E 63rd St Apt 19ENew York, NY 10065                    New York
# 1457  61-20 71st Ave Unit F2ARidgewood, NY 11385                    New York
# 4757  800 Grand Concourse Apt GmsBronx, NY 10451               United States
#
#              locality   sublocality     street_name          long_name  \
# 3014         New York  Bronx County       The Bronx  Longfellow Avenue
# 958      Bronx County     The Bronx  Spuyten Duyvil               2390
# 3139  New York County      New York       Manhattan                205
# 1457    Queens County        Queens       Ridgewood              61-20
# 4757         New York  Bronx County       The Bronx    Grand Concourse
#
#                                  formatted_address
# 3014     1893 Longfellow Ave, Bronx, NY 10460, USA
# 958    2390 Palisade Ave #4c, Bronx, NY 10463, USA
# 3139   205 E 63rd St #19e, New York, NY 10065, USA
# 1457  61-20 71st Ave #2f, Ridgewood, NY 11385, USA
# 4757     800 Grand Concourse, Bronx, NY 10451, USA
# time: 26.1 ms (started: 2024-01-13 13:52:39 +00:00)

# %% [markdown]
# In fact there are redundant features here.
# * **administrative_area_level_2 and 'locality:** I'm going to keep 'locality' because it looks cleaner and the county is important to the analysis.
# * **address, formatted_address and main_address:** I'm going to keep 'formatted_address' because as the name says the addresses are formated and will be easier to get some informations with split(',') function.
# * **state and street_name:** I'm going to keep state because the zip code may be important.

# %%
df[['state', 'locality', 'sublocality', 'long_name', 'formatted_address']].sample(10)
# Out:
#                         state         locality      sublocality  \
# 1026  Fresh Meadows, NY 11366         New York    Queens County
# 3238     Whitestone, NY 11357         New York    Queens County
# 1648       New York, NY 10025  New York County         New York
# 542   College Point, NY 11356         New York    Queens County
# 1218         Hollis, NY 11423         New York    Queens County
# 1289       Glendale, NY 11385         New York    Queens County
# 2590       Brooklyn, NY 11220     Kings County         Brooklyn
# 1283         Queens, NY 11372           Queens  Jackson Heights
# 3595       Brooklyn, NY 11221         New York     Kings County
# 3806  Staten Island, NY 10314         New York  Richmond County
#
#                long_name                                  formatted_address
# 1026        186th Street            75-57 186th St, Flushing, NY 11366, USA
# 3238        150th Street            20-08 150th St, Flushing, NY 11357, USA
# 1648                   7           7 W 92nd St #5g, New York, NY 10025, USA
# 542       Endeavor Place      327 Endeavor Pl, College Point, NY 11356, USA
# 1218         205th Place            100-03 205th Pl, Jamaica, NY 11423, USA
# 1289         66th Street             71-12 66th St, Flushing, NY 11385, USA
# 2590                4907          4907 4th Ave #3c, Brooklyn, NY 11220, USA
# 1283       The Belvedere  The Belvedere, 84-12 35th Ave #4c, Jackson Hei...
# 3595    Van Buren Street          595 Van Buren St, Brooklyn, NY 11221, USA
# 3806  Richmond Hill Road  263 Richmond Hill Rd, Staten Island, NY 10314,...
# time: 13.1 ms (started: 2024-01-13 13:52:39 +00:00)

# %% [markdown]
# The numbers in 'state' are the zip codes and consulting the [United States Zip Codes](https://www.unitedstateszipcodes.org/) website I've found out that the names before the comma was meant to be the post office because there are a lot of matches between the numbers and post office names. But still there are a lot of inconsistences not just in this feaure but 'locality', 'sublocality', and 'long_name'. None of them are reliable.
#
# I turns out that I'm going to extract the street names and zip codes from 'formatted_address' and remove them all.

# %% [markdown]
# ### Features creation
#
# Usually I remove and add attributes in the feature engineering step but the features I want to add will help the data visualization and analysis. Since I'm adding, I'm going to remove the unwanted ones now too.

# %%
df['zip_code'] = df['formatted_address'].apply(lambda address: int(re.findall(r"\d{5}", address)[0]))
# Out:
# time: 24.8 ms (started: 2024-01-13 13:52:39 +00:00)

# %% [markdown]
# I really don't know if this is cheating but I've found a file on github that seems much more realiable regarding zip code-borough than the features from this dataset.

# %%
url = 'https://github.com/erikgregorywebb/nyc-housing/blob/master/Data/nyc-zip-codes.csv?raw=true'
zip_codes = pd.read_csv(url)
zip_codes = zip_codes.rename(columns={'Borough':'borough', 'Neighborhood':'neighborhood', 'ZipCode':'zip_code'})
zip_codes.sample(5)
# Out:
#            borough     neighborhood  zip_code
# 113         Queens     North Queens     11358
# 120         Queens          Jamaica     11423
# 125         Queens          Jamaica     11436
# 91       Manhattan  Upper East Side     10021
# 168  Staten Island    Port Richmond     10310
# time: 428 ms (started: 2024-01-13 13:52:39 +00:00)

# %%
df = df.merge(zip_codes, on='zip_code')
df[['formatted_address', 'zip_code', 'borough', 'neighborhood']].sample(5)
# Out:
#                                   formatted_address  zip_code    borough  \
# 1554  2848 Brighton 4th St, Brooklyn, NY 11235, USA     11235   Brooklyn
# 1332       180 Thompson St, New York, NY 10012, USA     10012  Manhattan
# 1984       3652 De Reimer Ave, Bronx, NY 10466, USA     10466      Bronx
# 4612   282A Nassau Ave #3a, Brooklyn, NY 11222, USA     11222   Brooklyn
# 2373     444 E 75th St #7h, New York, NY 10021, USA     10021  Manhattan
#
#                     neighborhood
# 1554           Southern Brooklyn
# 1332  Greenwich Village and Soho
# 1984             Northeast Bronx
# 4612                  Greenpoint
# 2373             Upper East Side
# time: 23.3 ms (started: 2024-01-13 13:52:39 +00:00)

# %%
df['street_name'] = df['formatted_address'].apply(lambda address: address.split(',')[0])
df[['formatted_address', 'zip_code', 'borough', 'neighborhood', 'street_name']].sample(5)
# Out:
#                                     formatted_address  zip_code    borough  \
# 4013        111 4th Ave #12a, New York, NY 10003, USA     10003  Manhattan
# 1612   3028 Brighton 7th St., Brooklyn, NY 11235, USA     11235   Brooklyn
# 3490         32 Village Rd S, Brooklyn, NY 11223, USA     11223   Brooklyn
# 4028            1341 Fteley Ave, Bronx, NY 10472, USA     10472      Bronx
# 133   110 Central Park S #5a, New York, NY 10019, USA     10019  Manhattan
#
#              neighborhood             street_name
# 4013      Lower East Side        111 4th Ave #12a
# 1612    Southern Brooklyn   3028 Brighton 7th St.
# 3490    Southern Brooklyn         32 Village Rd S
# 4028      Southeast Bronx         1341 Fteley Ave
# 133   Chelsea and Clinton  110 Central Park S #5a
# time: 24.4 ms (started: 2024-01-13 13:52:39 +00:00)

# %%
df = df.drop(['address', 'state', 'main_address', 'administrative_area_level_2', 'locality', 'sublocality', 'long_name', 'formatted_address'], axis=1)
df.head(5)
# Out:
#                                          brokertitle                type  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                Brokered by COMPASS      Condo for sale
# 2  Brokered by Sotheby's International Realty - E...  Townhouse for sale
# 3                Brokered by AI Realty Brokerage LLC      Condo for sale
# 4  Brokered by Brown Harris Stevens - 445 Park Av...      Co-op for sale
#
#      price  beds  bath  propertysqft        street_name   latitude  longitude  \
# 0   315000     2     2          1400    Regis Residence  40.761255 -73.974483
# 1    69000     3     1           445        2 E 55th St  40.761398 -73.974613
# 2  1250000     8     2          2184      246 E 58th St  40.760025 -73.965355
# 3  2000000     4     4          3000  444 E 57th St #2d  40.757348 -73.961491
# 4  3950000     3     3          2184      2 Sutton Pl s  40.757395 -73.960655
#
#    zip_code    borough                   neighborhood
# 0     10022  Manhattan  Gramercy Park and Murray Hill
# 1     10022  Manhattan  Gramercy Park and Murray Hill
# 2     10022  Manhattan  Gramercy Park and Murray Hill
# 3     10022  Manhattan  Gramercy Park and Murray Hill
# 4     10022  Manhattan  Gramercy Park and Murray Hill
# time: 17.5 ms (started: 2024-01-13 13:52:39 +00:00)

# %% [markdown]
# ## Data Visualization

# %%
from sklearn.preprocessing import KBinsDiscretizer

import matplotlib.pyplot as plt
import seaborn           as sns

# %matplotlib inline
# Out:
# time: 5.36 ms (started: 2024-01-13 13:52:39 +00:00)

# %% [markdown]
# To investigate geographical patterns to identify areas with higher or lower property prices I'm going to group the continuous values of 'price' into contiguous intervals. This process will discretize the numbers.

# %%
kbd = KBinsDiscretizer(n_bins=10, encode='ordinal')
price_disc = kbd.fit_transform(df['price'].to_numpy().reshape(-1, 1)).ravel()

sns.set(rc={'figure.figsize':(15, 5)})
sns.scatterplot(data=df, x='longitude', y='latitude', hue=price_disc, palette=sns.color_palette("crest", as_cmap=True), sizes=(10, 200))
plt.tight_layout()
plt.show()
# Out:
# time: 953 ms (started: 2024-01-13 13:52:39 +00:00)

# %% [markdown]
# **Conclusion:** I wasn't able to see any useful patterns here.

# %% [markdown]
# ### Borough x Average Price

# %%
col = 'borough'
average_prices = df.groupby(col)['price'].mean().sort_values(ascending=False).index

sns.set(rc={'figure.figsize':(12, 4)})
sns.set(style="whitegrid")
axs = sns.barplot(data=df, x=col, y='price', order=average_prices, palette='viridis', errorbar=None)
axs.set(yticklabels=[])
plt.bar_label(axs.containers[0])
plt.tight_layout()
plt.show()
# Out:
# time: 720 ms (started: 2024-01-13 13:52:40 +00:00)

# %% [markdown]
# ### Neighborhood x Average Price

# %%
col = 'neighborhood'
average_prices = df.groupby(col)['price'].mean().sort_values(ascending=False).index

sns.set(rc={'figure.figsize':(12, 6)})
axs = sns.barplot(data=df, x=col, y='price', order=average_prices, palette='viridis', errorbar=None)
axs.set_xticklabels(axs.get_xticklabels(), rotation=90, ha="right")
plt.tight_layout()
plt.show()
# Out:
# time: 977 ms (started: 2024-01-13 13:52:41 +00:00)

# %% [markdown]
# ### Square Footage x Price

# %%
sns.set(rc={'figure.figsize':(12, 5)})
axs = sns.lineplot(data=df, x='propertysqft', y='price')
plt.tight_layout()
plt.show()
# Out:
# time: 28.8 s (started: 2024-01-13 13:52:42 +00:00)

# %%
# zooming in the plot keeping only properties smaller than 10_000
mask = df['propertysqft'] < 10_000
df_ = df[mask]

sns.set(rc={'figure.figsize':(12, 7)})
axs = sns.lineplot(data=df_, x='propertysqft', y='price')
plt.tight_layout()
plt.show()
# Out:
# time: 16.5 s (started: 2024-01-13 13:53:11 +00:00)

# %% [markdown]
# There is too much noise! I'm going to discretize 'propertysqft' attribute too. Maybe with price_disc I can find a pattern.

# %%
kbd = KBinsDiscretizer(n_bins=5, encode='ordinal')
sqft_disc = kbd.fit_transform(df['propertysqft'].to_numpy().reshape(-1, 1)).ravel()

sns.set(rc={'figure.figsize':(12, 5)})
axs = sns.lineplot(x=sqft_disc, y=price_disc)
plt.tight_layout()
plt.show()
# Out:
# time: 640 ms (started: 2024-01-13 13:53:27 +00:00)

# %% [markdown]
# **Conclusion:** Despite all the noise the data appears to have an ascending trend as property sizes increase.

# %% [markdown]
# ### Property Type x Average Price

# %%
col = 'type'
average_prices = df.groupby(col)['price'].mean().sort_values(ascending=False).index

sns.set(rc={'figure.figsize':(12, 6)})
sns.set(style="whitegrid")
axs = sns.barplot(data=df, x=col, y='price', order=average_prices, palette='viridis', errorbar=None)
axs.set(yticklabels=[])
axs.set_xticklabels(axs.get_xticklabels(), rotation=90, ha="right")
plt.tight_layout()
plt.show()
# Out:
# time: 422 ms (started: 2024-01-13 13:53:28 +00:00)

# %% [markdown]
# ### Beds x Average Price

# %%
col = 'beds'

mask = df[col] < 12 # by calling value_counts() I could see there are very few instances with more than 12 beds so I'm ignoring them now
df_ = df[mask]

average_prices = df_.groupby(col)['price'].mean().sort_values(ascending=False).index

sns.set(rc={'figure.figsize':(12, 4)})
sns.set(style="whitegrid")
axs = sns.barplot(data=df_, x=col, y='price', order=average_prices, palette='viridis', errorbar=None)
axs.set(yticklabels=[])
axs.set_xticklabels(axs.get_xticklabels(), rotation=90, ha="right")
plt.tight_layout()
plt.show()
# Out:
# time: 349 ms (started: 2024-01-13 13:53:28 +00:00)

# %% [markdown]
# ### Bath x Average Price

# %%
col = 'bath'

mask = df[col] < 10 # by calling value_counts() I could see there are very few instances with more than 10 baths so I'm ignoring them now
df_ = df[mask]

average_prices = df_.groupby(col)['price'].mean().sort_values(ascending=False).index

sns.set(rc={'figure.figsize':(12, 4)})
sns.set(style="whitegrid")
axs = sns.barplot(data=df_, x=col, y='price', order=average_prices, palette='viridis', errorbar=None)
axs.set(yticklabels=[])
axs.set_xticklabels(axs.get_xticklabels(), rotation=90, ha="right")
plt.tight_layout()
plt.show()
# Out:
# time: 515 ms (started: 2024-01-13 13:53:29 +00:00)

# %% [markdown]
# ## Statistical test
# To analyze the impact of the number of bedrooms and bathrooms on house prices and the broker's influence on the pricing of houses as well I'm going to do a statistical test called Mutual information.
#
#
# Bellow you can see the ranking of influence on the house pricing.
#
# But first I'm going to make another feature transformation that I'm not use to do here in the data analysis. By calling value_counts() on 'brokertitle' you can see that there 505 unique values of 1016. Im' going to combine them in one name 'Brokered by Others'.

# %%
# %pip install category-encoders
# Out:
# Requirement already satisfied: category-encoders in /usr/local/lib/python3.10/dist-packages (2.6.3)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from category-encoders) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from category-encoders) (1.2.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from category-encoders) (1.11.4)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from category-encoders) (0.14.1)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.10/dist-packages (from category-encoders) (1.5.3)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.10/dist-packages (from category-encoders) (0.5.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category-encoders) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.5->category-encoders) (2023.3.post1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.1->category-encoders) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category-encoders) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->category-encoders) (3.2.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.9.0->category-encoders) (23.2)
# time: 8.45 s (started: 2024-01-13 13:53:29 +00:00)

# %%
from category_encoders.leave_one_out import LeaveOneOutEncoder
from sklearn.feature_selection       import mutual_info_regression

import numpy as np
# Out:
# time: 872 µs (started: 2024-01-13 13:53:38 +00:00)

# %%
'''
df['brokertitle'] = df['brokertitle'].apply(lambda bt: bt if df['brokertitle'].value_counts()[bt] >= 10 else 'Brokered by Others')
df['brokertitle'].value_counts()
'''
# Out:
# "\ndf['brokertitle'] = df['brokertitle'].apply(lambda bt: bt if df['brokertitle'].value_counts()[bt] >= 10 else 'Brokered by Others')\ndf['brokertitle'].value_counts()\n"
# time: 4.73 ms (started: 2024-01-13 13:53:38 +00:00)

# %%
label = df['price'].values
bt_encoded = LeaveOneOutEncoder().fit_transform(df['brokertitle'], label)
matrix     = np.concatenate((bt_encoded, df[['beds', 'bath']].to_numpy()), axis=1)

scores = mutual_info_regression(X=matrix, y=label, discrete_features=[1, 2])
pd.Series(data=scores, index=['brokertitle', 'beds', 'bath']).sort_values(ascending=False)
# Out:
# brokertitle    0.973254
# bath           0.380641
# beds           0.256517
# dtype: float64
# time: 359 ms (started: 2024-01-13 13:58:07 +00:00)

# %% [markdown]
# # Train/Test split

# %%
from sklearn.model_selection import train_test_split
# Out:
# time: 577 µs (started: 2024-01-13 13:53:38 +00:00)

# %%
train_set, test_set = train_test_split(df, test_size=0.2)
# Out:
# time: 6.32 ms (started: 2024-01-13 13:53:38 +00:00)

# %% [markdown]
# # Feature engineering

# %%
from sklearn.base          import BaseEstimator, TransformerMixin
from sklearn.compose       import ColumnTransformer
from sklearn.pipeline      import Pipeline
from sklearn.preprocessing import StandardScaler
# Out:
# time: 898 µs (started: 2024-01-13 13:53:38 +00:00)

# %% [markdown]
# The ColumnTransformer class by default returns a numpy array meaning I lose the column names but I think is easier to manage the features that are going to be transformed using their names. To do that I can use set_output(transform='pandas') function but the problem is the names are slightly different from the originals. To fix this I created the class bellow that creates a Pandas DrataFrame object with the original features names.

# %%
class FeaturesRenamer(BaseEstimator, TransformerMixin):
  def __init__(self, original_names):
    if isinstance(original_names, list):
      self.original_names = original_names
    else:
      self.original_names = list(original_names)
  def fit(self, X, y=None):
    return self
  def fit_transform(self, X, y=None):
    self.fit(X, y)
    return self.transform(X, y)
  def transform(self, X, y=None):
    new_names = list()
    for name in list(X.columns):
      for original in self.original_names:
        if name.endswith('__' + original):
          new_names.append(original)
    return X.set_axis(new_names, axis=1)
# Out:
# time: 5.44 ms (started: 2024-01-13 13:53:38 +00:00)

# %% [markdown]
# Getting the categorical e numerical feauture names.

# %%
numerical = list()
categorical = list()
[numerical.append(feature) if df[feature].dtype != 'object' else categorical.append(feature) for feature in df.columns]

print(categorical)
print(numerical)
# Out:
# ['brokertitle', 'type', 'street_name', 'borough', 'neighborhood']
# ['price', 'beds', 'bath', 'propertysqft', 'latitude', 'longitude', 'zip_code']
# time: 5.88 ms (started: 2024-01-13 13:53:38 +00:00)

# %% [markdown]
# ## Categorical features

# %% [markdown]
# **Step ## -** NaN values - Imputation

# %%
df[categorical].isnull().sum()
# Out:
# brokertitle     0
# type            0
# street_name     0
# borough         0
# neighborhood    0
# dtype: int64
# time: 35.1 ms (started: 2024-01-13 14:11:03 +00:00)

# %% [markdown]
# **Step ## -** Nominal features - Encoding

# %%
ct_encoder = ColumnTransformer(transformers=[('loenc', LeaveOneOutEncoder(), categorical)], remainder='passthrough')
ct_encoder.set_output(transform='pandas')
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('loenc', LeaveOneOutEncoder(),
#                                  ['brokertitle', 'type', 'street_name',
#                                   'borough', 'neighborhood'])])
# time: 12.4 ms (started: 2024-01-13 14:09:25 +00:00)

# %% [markdown]
# ## Numerical features

# %% [markdown]
# **Step ## -** NaN - Imputation

# %%
df[numerical].isnull().sum()
# Out:
# price           0
# beds            0
# bath            0
# propertysqft    0
# latitude        0
# longitude       0
# zip_code        0
# dtype: int64
# time: 11.4 ms (started: 2024-01-13 14:11:16 +00:00)

# %% [markdown]
# **Step ## -** Outliers - Replacement by median.

# %%
class OutliersZScoreReplacer(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        self.mean_std_median = list()
        for name in X.columns:
            mean   = X[name].mean()
            std    = X[name].std()
            median = X[name].median()
            self.mean_std_median.append((mean, std, median))
        return self

    def fit_transform(self, X, y=None):
        self.fit(X, y)
        return self.transform(X, y)

    def get_feature_names_out(self):
        pass

    def transform(self, X, y=None):
        std_unit = 3
        for index, name in enumerate(X.columns):
            mean    = self.mean_std_median[index][0]
            std     = self.mean_std_median[index][1]
            median  = self.mean_std_median[index][2]
            scores  = ((X[name] - mean) / std)
            filter_mask = ((scores < -std_unit) | (scores > std_unit))
            X.loc[filter_mask, name] = median
        return X



ct_outliers = ColumnTransformer(transformers=[('outlireszsreplacer', OutliersZScoreReplacer(), numerical)], remainder='passthrough')
ct_outliers.set_output(transform='pandas')

# %% [markdown]
# ## Pipeline

# %%
steps = [('ct_encoder', ct_encoder),
         ('renamer01', FeaturesRenamer(df.columns)),
         ('ct_outliers', ct_outliers),
         ('renamer02', FeaturesRenamer(df.columns))]

pipeline = Pipeline(steps=steps)
train_set = pipeline.fit_transform(train_set, train_set['price'])
test_set  = pipeline.transform(test_set)
# Out:
# time: 428 ms (started: 2024-01-13 14:20:22 +00:00)

# %% [markdown]
# ## Getting the labels

# %%
y_train = train_set['price']
y_test  = test_set['price']

X_train = train_set.drop('price', axis=1)
X_test  = test_set.drop('price', axis=1)

# %% [markdown]
# # Model training
#
# Candidate models:
# * Baseline
#  * DummyRegressor
# * Linear
#  * ElasticNet
#  * SVR
# * Tree based
#  * RandomForestRegressor
#  * XGBRegressor
#
# I'm going to use cross validatoin in order to evaluate the candidates except the baseline.
